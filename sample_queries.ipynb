# %% [markdown]
# <h1> Test Queries </h1>

# %% [markdown]
# <h2> Query 1 </h2>

# %% [markdown]
# ![query1.JPG](attachment:query1.JPG)

# %% [markdown]
# ![query1_result.JPG](attachment:query1_result.JPG)

# %% [markdown]
# <h2> Query 2 </h2>

# %% [markdown]
# ![query2.JPG](attachment:query2.JPG)

# %% [markdown]
# ![query2_result.JPG](attachment:query2_result.JPG)

# %% [markdown]
# <h2> Query 3 </h2>

# %% [markdown]
# ![query3.JPG](attachment:query3.JPG)

# %% [markdown]
# ![query3_result.JPG](attachment:query3_result.JPG)

# %% [markdown]
# <h2> Query 4 </h2>

# %% [markdown]
# ![query4.JPG](attachment:query4.JPG)

# %% [markdown]
# ![query4_result.JPG](attachment:query4_result.JPG)

# %% [markdown]
# <h2> Query 5a - 5e</h2>

# %% [markdown]
# ![query5a.JPG](attachment:query5a.JPG)

# %% [markdown]
# ![query5a_result.JPG](attachment:query5a_result.JPG)

# %% [markdown]
# ![query5b.JPG](attachment:query5b.JPG)

# %% [markdown]
# ![query5b_results.JPG](attachment:query5b_results.JPG)

# %% [markdown]
# ![query5c.JPG](attachment:query5c.JPG)

# %% [markdown]
# ![query5c_result.JPG](attachment:query5c_result.JPG)

# %% [markdown]
# ![query5d.JPG](attachment:query5d.JPG)

# %% [markdown]
# ![query5d_result.JPG](attachment:query5d_result.JPG)

# %% [markdown]
# ![query5e.JPG](attachment:query5e.JPG)

# %% [markdown]
# ![query5e_result.JPG](attachment:query5e_result.JPG)
